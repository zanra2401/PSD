# %% [markdown]
# # Pembersihan Outliers

# %% [markdown]
# ## Data Iris

# %%
import pandas as pd
from module.dataTransformer import combineData
from module.fetcher import fetchDataMysql, fetchDataPg

data_pg = fetchDataPg("SELECT petal_length, petal_width, species FROM iris_table")
data_my = fetchDataMysql("SELECT sepal_length, sepal_width FROM iris_table")

iris_df = combineData(data1=data_my, data2=data_pg)
iris_df
# Out:
#     sepal_length sepal_width petal_length petal_width         species
# 0           5.10        3.50         1.40        0.20     Iris-setosa
# 1           4.90        3.00         1.40        0.20     Iris-setosa
# 2           4.70        3.20         1.30        0.20     Iris-setosa
# 3           4.60        3.10         1.50        0.20     Iris-setosa
# 4           5.00        3.60         1.40        0.20     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145         6.70        3.00         5.20        2.30  Iris-virginica
# 146         6.30        2.50         5.00        1.90  Iris-virginica
# 147         6.50        3.00         5.20        2.00  Iris-virginica
# 148         6.20        3.40         5.40        2.30  Iris-virginica
# 149         5.90        3.00         5.10        1.80  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Menyiyngkirkan kolom species (class) 
numeric_iris_df = iris_df[["sepal_length", "sepal_width", "petal_length", "petal_width"]]

# %% [markdown]
# ## Model ABOD
#
# Membuat model ABOD dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

abod_model = create_model("abod", fraction=0.05)

df_abod = assign_model(abod_model)

df_abod
# Out:
# <style type="text/css">
# #T_fe568_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fe568">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe568_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fe568_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe568_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe568_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fe568_row0_col1" class="data row0 col1" >5377</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe568_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_fe568_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe568_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_fe568_row2_col1" class="data row2 col1" >(150, 123)</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe568_row3_col0" class="data row3 col0" >Categorical features</td>
#       <td id="T_fe568_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe568_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_fe568_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe568_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_fe568_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe568_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_fe568_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fe568_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_fe568_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fe568_row8_col0" class="data row8 col0" >Maximum one-hot encoding</td>
#       <td id="T_fe568_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fe568_row9_col0" class="data row9 col0" >Encoding method</td>
#       <td id="T_fe568_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fe568_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_fe568_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fe568_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_fe568_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fe568_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_fe568_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fe568_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_fe568_row13_col1" class="data row13 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fe568_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fe568_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_fe568_row14_col1" class="data row14 col1" >2166</td>
#     </tr>
#   </tbody>
# </table>
#     sepal_length sepal_width petal_length petal_width  Anomaly  Anomaly_Score
# 0           5.10        3.50         1.40        0.20        0      -0.002695
# 1           4.90        3.00         1.40        0.20        0      -0.000938
# 2           4.70        3.20         1.30        0.20        0      -0.005625
# 3           4.60        3.10         1.50        0.20        0      -0.001406
# 4           5.00        3.60         1.40        0.20        0      -0.000820
# ..           ...         ...          ...         ...      ...            ...
# 145         6.70        3.00         5.20        2.30        1      -0.000195
# 146         6.30        2.50         5.00        1.90        0      -0.000271
# 147         6.50        3.00         5.20        2.00        0      -0.000938
# 148         6.20        3.40         5.40        2.30        0      -0.000316
# 149         5.90        3.00         5.10        1.80        0      -0.000938
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS clean
#
# Data Tanpa Outliers

# %%
clean_iris_abod = df_abod[df_abod["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_abod
# Out:
#     sepal_length sepal_width petal_length petal_width         species
# 0           5.10        3.50         1.40        0.20     Iris-setosa
# 1           4.90        3.00         1.40        0.20     Iris-setosa
# 2           4.70        3.20         1.30        0.20     Iris-setosa
# 3           4.60        3.10         1.50        0.20     Iris-setosa
# 4           5.00        3.60         1.40        0.20     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 144         6.70        3.30         5.70        2.50  Iris-virginica
# 146         6.30        2.50         5.00        1.90  Iris-virginica
# 147         6.50        3.00         5.20        2.00  Iris-virginica
# 148         6.20        3.40         5.40        2.30  Iris-virginica
# 149         5.90        3.00         5.10        1.80  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data abod_iris_clean.csv](abod_iris_clean.csv)

# %%
clean_iris_abod.to_csv("abod_iris_clean.csv")

# %% [markdown]
# ## Model iforest
#
# Membuat model iforest dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

iforest_model = create_model("iforest", fraction=0.05)

df_iforest = assign_model(iforest_model)

df_iforest
# Out:
# <style type="text/css">
# #T_e8907_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8907_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8907_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8907_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8907_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e8907_row0_col1" class="data row0 col1" >3673</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8907_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e8907_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8907_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_e8907_row2_col1" class="data row2 col1" >(150, 123)</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8907_row3_col0" class="data row3 col0" >Categorical features</td>
#       <td id="T_e8907_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8907_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_e8907_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8907_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_e8907_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8907_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_e8907_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8907_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_e8907_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8907_row8_col0" class="data row8 col0" >Maximum one-hot encoding</td>
#       <td id="T_e8907_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8907_row9_col0" class="data row9 col0" >Encoding method</td>
#       <td id="T_e8907_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e8907_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_e8907_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e8907_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_e8907_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e8907_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_e8907_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e8907_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_e8907_row13_col1" class="data row13 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e8907_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e8907_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_e8907_row14_col1" class="data row14 col1" >6779</td>
#     </tr>
#   </tbody>
# </table>
#     sepal_length sepal_width petal_length petal_width  Anomaly  Anomaly_Score
# 0           5.10        3.50         1.40        0.20        0      -0.028024
# 1           4.90        3.00         1.40        0.20        0      -0.030777
# 2           4.70        3.20         1.30        0.20        0      -0.035469
# 3           4.60        3.10         1.50        0.20        0      -0.015281
# 4           5.00        3.60         1.40        0.20        0      -0.025525
# ..           ...         ...          ...         ...      ...            ...
# 145         6.70        3.00         5.20        2.30        0      -0.024522
# 146         6.30        2.50         5.00        1.90        0      -0.020970
# 147         6.50        3.00         5.20        2.00        0      -0.009199
# 148         6.20        3.40         5.40        2.30        0      -0.015559
# 149         5.90        3.00         5.10        1.80        0      -0.035553
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS Clean
#
# Data Tanpa Outliers

# %%
clean_iris_iforest = df_iforest[df_iforest["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_iforest
# Out:
#     sepal_length sepal_width petal_length petal_width         species
# 0           5.10        3.50         1.40        0.20     Iris-setosa
# 1           4.90        3.00         1.40        0.20     Iris-setosa
# 2           4.70        3.20         1.30        0.20     Iris-setosa
# 3           4.60        3.10         1.50        0.20     Iris-setosa
# 4           5.00        3.60         1.40        0.20     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145         6.70        3.00         5.20        2.30  Iris-virginica
# 146         6.30        2.50         5.00        1.90  Iris-virginica
# 147         6.50        3.00         5.20        2.00  Iris-virginica
# 148         6.20        3.40         5.40        2.30  Iris-virginica
# 149         5.90        3.00         5.10        1.80  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data iforest_iris_clean.csv](iforest_iris_clean.csv)

# %%
clean_iris_iforest.to_csv("iforest_iris_clean.csv")

# %% [markdown]
# ## Model LOF
# Membuat model LOF dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

lof_model = create_model("lof", fraction=0.05)

df_lof = assign_model(lof_model)

df_lof
# Out:
# <style type="text/css">
# #T_c5190_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c5190">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5190_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c5190_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5190_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5190_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c5190_row0_col1" class="data row0 col1" >8671</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5190_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_c5190_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5190_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_c5190_row2_col1" class="data row2 col1" >(150, 123)</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5190_row3_col0" class="data row3 col0" >Categorical features</td>
#       <td id="T_c5190_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5190_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_c5190_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5190_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_c5190_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5190_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_c5190_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c5190_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_c5190_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c5190_row8_col0" class="data row8 col0" >Maximum one-hot encoding</td>
#       <td id="T_c5190_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c5190_row9_col0" class="data row9 col0" >Encoding method</td>
#       <td id="T_c5190_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c5190_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_c5190_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c5190_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_c5190_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c5190_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_c5190_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c5190_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_c5190_row13_col1" class="data row13 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c5190_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c5190_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_c5190_row14_col1" class="data row14 col1" >31d8</td>
#     </tr>
#   </tbody>
# </table>
#     sepal_length sepal_width petal_length petal_width  Anomaly  Anomaly_Score
# 0           5.10        3.50         1.40        0.20        0       0.997672
# 1           4.90        3.00         1.40        0.20        0       0.993906
# 2           4.70        3.20         1.30        0.20        0       1.001341
# 3           4.60        3.10         1.50        0.20        0       0.992439
# 4           5.00        3.60         1.40        0.20        0       0.993568
# ..           ...         ...          ...         ...      ...            ...
# 145         6.70        3.00         5.20        2.30        0       0.989725
# 146         6.30        2.50         5.00        1.90        0       1.023798
# 147         6.50        3.00         5.20        2.00        0       0.992359
# 148         6.20        3.40         5.40        2.30        0       1.003787
# 149         5.90        3.00         5.10        1.80        0       0.993543
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS clean
#
# Data Tanpa Outliers

# %%
clean_iris_lof = df_lof[df_lof["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_lof
# Out:
#     sepal_length sepal_width petal_length petal_width         species
# 0           5.10        3.50         1.40        0.20     Iris-setosa
# 1           4.90        3.00         1.40        0.20     Iris-setosa
# 2           4.70        3.20         1.30        0.20     Iris-setosa
# 3           4.60        3.10         1.50        0.20     Iris-setosa
# 4           5.00        3.60         1.40        0.20     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145         6.70        3.00         5.20        2.30  Iris-virginica
# 146         6.30        2.50         5.00        1.90  Iris-virginica
# 147         6.50        3.00         5.20        2.00  Iris-virginica
# 148         6.20        3.40         5.40        2.30  Iris-virginica
# 149         5.90        3.00         5.10        1.80  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data lof_iris_clean.csv](lof_iris_clean.csv)

# %%
clean_iris_lof.to_csv("lof_iris_clean.csv")
